# %% [markdown]
# ### This file extracts audio files from directories.
# 将所有文件夹内的音频提取特征，并每一类分别存储到一个路径

# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %%
np.__version__
# Out:
# '1.23.3'

# %%
root_dir = "/data2/xiangrui_d2/MMC/Dataset/Combine/wav/Moby/wav/Train"
seg = 240
sample_rate = 8000
save_dir = "/data2/xiangrui_d2/MMC/Dataset/Combine/features/Moby/pyramid/train"
if os.path.exists(save_dir):
    pass
else:
    os.mkdir(save_dir)

# %%
def slicing_and_padding_single_data(data,seg=30):
    """_summary_

    Args:
        data_list (_type_): A data list that contains 2D arrays data.
        seg (int, optional): The length of each sliced data. Defaults to 30.
    """
    new_data_list = []

    data_length = data.shape[0] # The length of original 2D data sample.
    seg_counter = 0
    while data_length > 0:
        if data_length>=seg:

            new_data_list.append(data[seg_counter:seg_counter + seg,:])
            data_length -= seg
            seg_counter += seg

        elif data_length >= seg/2:  #when the left data_length is less than seg size but large than half of seg size, pad it up to seg size
            
            # pad the sample mean
            # average = data.mean(axis=0)
            # missing_length = seg-data_length
            # averages_pads = np.tile(average,(missing_length,1))
            # padded_data = np.vstack((data[seg_counter:,:],averages_pads))
            # print(padded_data.shape)
        
            #pad 0s 
            pad = np.zeros((seg-data_length,data.shape[1]))
            padded_data = np.vstack((data[seg_counter:,:],pad))

            # print(padded_data.shape)
            new_data_list.append(padded_data)
            break
        else: #when the row number is less than half of the segment , pass the rows.
            break
    return new_data_list

# %%
def batch_feature_extraction(dir,sample_rate,seg=seg,):
    """_summary_

    Args:
        dir (_type_): Root folder directory that contains differents classes' folders.

    Returns:
        _type_: spectrogram list, mfcc list
    """
 
    # Save the folders' directories to a list according to the classes.
    
    folder_list = []
    class_list = []
    for root,folders,files in os.walk(dir):
        for folder in folders:


            folder_list.append(os.path.join(root,folder))
            class_list.append(folder)

    print(class_list)
    for folder_dir,class_name in zip(folder_list,class_list):
        
        specs = []
        # mfccs = []
        print('going through folder',folder_dir)
        for file in os.listdir(folder_dir):
            
            if file.endswith(".csv"):
                continue

            audio_name = file
            audio_dir = os.path.join(folder_dir,audio_name)
            # print(audio_dir)
            
            y, sr = librosa.load(audio_dir,sr=sample_rate) #default sample rate 22050
            if len(y)<2048:
                print('The length of audio is less than 2048 samples ',audio_dir)
                continue
            
            # Calculate spectrogram
            spec = librosa.feature.melspectrogram(y=y,sr=sr,n_mels=240)
            spec = librosa.power_to_db(spec)
            spec = spec.T
            # print(spec.shape)
            modified_spec = slicing_and_padding_single_data(spec,seg=seg)
            specs.extend(modified_spec)           
        

#-------------------------------------------------------------------------------------------
# Assert that all the data has correct shape
        print('There are {} sliced and padded data samples under \n{}\n'.format(len(specs),folder_dir))
        
        for i in specs:
            assert i.shape[0]==seg,print(i.shape)

#-------------------------------------------------------------------------------------------
# Save the data into csv files to respective directories
        specs = np.array(specs)

        # reshaped_specs = specs.reshape(specs.shape[0],-1)
        current_labels = np.full((specs.shape[0],1),class_name)
        np.savez(os.path.join(save_dir,class_name+'_specs.csv'),specs,current_labels)
        # np.savetxt(os.path.join(folder_dir,'specs.csv'), reshaped_specs, delimiter=",")


batch_feature_extraction(root_dir,sample_rate=sample_rate,seg=seg)
# Out:
# There are 0 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Ringed Seal
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Tucuxi Dolphin
# There are 0 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Tucuxi Dolphin
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/71002023.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/7100200M.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/7100202G.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/7100200F.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/7100201S.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/71002003.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/7100200J.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/7100201F.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/7100700B.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/71002009.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/71002004.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/7100200O.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/7100200L.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/7100201Q.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/71007007.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/7100200P.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/7100200Z.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/7100200I.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/7100700A.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/7100700W.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/71002001.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/71007008.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/71002008.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/7100201D.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/71002002.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/7100200N.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin/7100200Y.wav
# There are 100 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Spinner Dolphin
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Leopard Seal
# There are 3 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Leopard Seal
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Hooded Seal
# There are 0 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Hooded Seal
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Northern Right Whale
# There are 0 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Northern Right Whale
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Fraser's Dolphin
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Fraser's Dolphin/9400903T.wav
# There are 27 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Fraser's Dolphin
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Grampus, Risso's Dolphin
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Grampus, Risso's Dolphin/59030034.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Grampus, Risso's Dolphin/8500900K.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Grampus, Risso's Dolphin/59030019.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Grampus, Risso's Dolphin/94201039.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Grampus, Risso's Dolphin/9420101Y.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Grampus, Risso's Dolphin/5902900V.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Grampus, Risso's Dolphin/9420102I.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Grampus, Risso's Dolphin/8500900B.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Grampus, Risso's Dolphin/5903000U.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Grampus, Risso's Dolphin/94201014.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Grampus, Risso's Dolphin/8500900G.wav
# There are 4 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Grampus, Risso's Dolphin
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Blue Whale
# There are 28 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Blue Whale
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Sea Otter
# There are 0 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Sea Otter
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/False Killer Whale
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/False Killer Whale/6102105I.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/False Killer Whale/6102102S.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/False Killer Whale/6102104A.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/False Killer Whale/6102104O.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/False Killer Whale/61021050.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/False Killer Whale/6102104P.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/False Killer Whale/6102104J.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/False Killer Whale/6102104Z.wav
# There are 13 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/False Killer Whale
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Striped Dolphin
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Striped Dolphin/8501200J.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Striped Dolphin/8501200L.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Striped Dolphin/8501205Z.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Striped Dolphin/8501200Q.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Striped Dolphin/8501200O.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Striped Dolphin/8501200K.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Striped Dolphin/5801101I.wav
# There are 4 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Striped Dolphin
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/White-sided Dolphin
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/White-sided Dolphin/61075005.wav
# There are 6 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/White-sided Dolphin
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Irawaddy Dolphin
# There are 0 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Irawaddy Dolphin
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Narwhal
# There are 0 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Narwhal
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/White-beaked Dolphin
# There are 2 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/White-beaked Dolphin
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise/79024016.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise/79024017.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise/79024012.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise/7902400T.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise/7902400X.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise/79024015.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise/79024010.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise/79024014.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise/7902400N.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise/7902400R.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise/79024013.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise/7902400Y.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise/7902400P.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise/7902400Q.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise/7902400W.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise/7902400O.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise/7902400Z.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise/7902400U.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise/79024011.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise/7902400S.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise/7902400V.wav
# There are 1 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Dall's Porpoise
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Walrus
# There are 34 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Walrus
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Killer Whale
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Killer Whale/9750401D.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Killer Whale/9750400R.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Killer Whale/9750403X.wav
# There are 47 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Killer Whale
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Minke Whale
# There are 12 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Minke Whale
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Harbour Seal
# There are 0 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Harbour Seal
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Gray Whale
# There are 3 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Gray Whale
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Clymene Dolphin
# There are 22 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Clymene Dolphin
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Spotted Seal
# There are 0 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Spotted Seal
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Boutu, Amazon River Dolphin
# There are 0 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Boutu, Amazon River Dolphin
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Bowhead Whale
# There are 19 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Bowhead Whale
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Heaviside's Dolphin
# There are 3 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Heaviside's Dolphin
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Long Beaked (Pacific) Common Dolphin
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Long Beaked (Pacific) Common Dolphin/5802100R.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Long Beaked (Pacific) Common Dolphin/5802100M.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Long Beaked (Pacific) Common Dolphin/5802100F.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Long Beaked (Pacific) Common Dolphin/5802100S.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Long Beaked (Pacific) Common Dolphin/58036011.wav
# There are 11 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Long Beaked (Pacific) Common Dolphin
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Beluga, White Whale
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Beluga, White Whale/62022008.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Beluga, White Whale/62022007.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Beluga, White Whale/62022005.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Beluga, White Whale/62022002.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Beluga, White Whale/6202200O.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Beluga, White Whale/62022006.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Beluga, White Whale/62022003.wav
# There are 2 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Beluga, White Whale
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Atlantic Spotted Dolphin
# There are 9 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Atlantic Spotted Dolphin
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101202Q.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203B.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/91012040.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/91012037.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203O.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101202H.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203K.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/91012038.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203W.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101204D.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101204B.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203Q.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101204E.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/91012049.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101204A.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101202R.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/91012043.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101202S.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203C.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101202T.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203U.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101202W.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203L.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203A.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203S.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101202N.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/91012032.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203V.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101202Z.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101202L.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/91012047.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/91012042.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/91012046.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203H.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101202O.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203N.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203R.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/91012045.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203G.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101202M.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203X.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/91012036.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203E.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101202U.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/91012044.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101202V.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101202K.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203I.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/91012031.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101202P.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101202Y.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101202I.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/91012030.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101204C.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/91012039.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203P.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203M.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101202X.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/91012041.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203T.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101203F.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/91012048.wav
# The length of audio is less than 2048 samples  /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale/9101202J.wav
# There are 8 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Melon Headed Whale
#
# going through folder /home/assa8945/MMC/Dataset/Watkins_full/Bearded Seal
# There are 47 sliced and padded data samples under
# /home/assa8945/MMC/Dataset/Watkins_full/Bearded Seal

# %%
merged_X = np.zeros((1,240,240))
merged_y = np.zeros((1,1))

for file in os.listdir(save_dir):
    curr_npy = os.path.join(save_dir,file)
    # print(curr_npy)
    curr_data = np.load(curr_npy)
    X = curr_data['arr_0']
    y = curr_data['arr_1']
    if X.shape[0] ==0:
        continue
    merged_X = np.vstack((merged_X,X))
    merged_y = np.vstack((merged_y,y))
print(merged_X.shape)
print(merged_y.shape)
# Out:
# (4895, 240, 240)
# (4895, 1)

# %%
data2 = np.load("/home/assa8945/MMC/Dataset/features/watkins_full/v2_overall.npz")

# %%
xx = data2['arr_0']
yy = data2['arr_1']

# %%
yy.shape
# Out:
# (56069,)
